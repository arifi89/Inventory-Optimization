# %% [markdown]
# # 07 - Before/After Scenario Analysis
# ## Compare current vs optimized inventory levels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
