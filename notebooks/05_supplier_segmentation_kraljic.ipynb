# %% [markdown]
# # 05 - Supplier Segmentation (Kraljic Matrix)
# ## Strategic supplier classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
