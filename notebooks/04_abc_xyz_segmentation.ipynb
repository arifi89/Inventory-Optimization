# %% [markdown]
# # 04 - ABC-XYZ Segmentation
# ## Product segmentation based on value and demand variability

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
